# %% [markdown]
# # Week 2 - Monday Lesson (variable assignment, loops, lists)

# %% [markdown]
# ## Tasks Today:
#
# 1) Int & Float assignments <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Assigning int <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Assigning float <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Performing Calculations on ints and floats <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Addition <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Subtraction <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Multiplication <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Division <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Floor Division <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Modulo <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Exponential <br>
# 2) String Input-Output <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) String Assignment <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) print() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) String Concatenation <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Escape Characters <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Type Conversion <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) format() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Old Way (python 2) <br>
# 3) <b>In-Class Exercise #1</b> <br>
# 4) Booleans <br>
# 5) If Statements <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) syntax <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) truth tree <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) and/or <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) elif <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; 3) else <br>
# 6) <b>In-Class Exercise #2</b> <br>
# 7) Lists <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Declaring Lists <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Indexing a List <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) .append() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) .insert() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) .pop() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) .remove() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) del() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; h) Concatenating Two Lists <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) Lists Within Lists <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; j) Looping Through Lists <br>
# 8) For Loops <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Using 'in' keyword <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Continue Statement <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) Break Statement <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Pass Statement <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Double For Loops <br>
# 9) While Loops <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Looping 'While True' <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) While and For Loops Used Together <br>
# 10) Built-In Functions <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) input() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) range() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) len() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) help() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) isinstance() <br>
# 12) Try and Except <br>

# %% [markdown]
# ### Int & Float Assignments

# %% [markdown]
# ##### Assigning int

# %%
# variable_name = value
num_int = 6

print(num_int)

# %% [markdown]
# ##### Assinging float

# %%
num_float = 6.9344

print(num_float)
# Out:
# 6.9344

# %% [markdown]
# #### Performing Calculations on ints and floats

# %% [markdown]
# ##### Addition

# %%
num1 = 2
num2 = 5.0

result = num1 + num2
print(result)
print(type(result))
# Out:
# 7.0
# <class 'float'>

# %%
#short-hand version of adding to exisiting variable
result += 2 # result = result + 2

print(result)

# %% [markdown]
# ##### Subtraction

# %%
diff = num2 - num1
print(diff)

# short-hand
diff -= 2 # diff = diff - 2
print(diff)
# Out:
# 3.0
# 1.0

# %% [markdown]
# ##### Multiplication

# %%
prod = num1 * num2
print(prod)

# short-hand
prod *= 2 # prod = prod * 2
print(prod)
# Out:
# 10.0
# 20.0

# %% [markdown]
# ##### Division

# %%
quotient = 16 / num1 # division will always result in a float
print(quotient)
print(type(quotient))

#short-hand
quotient /= 2 # quotient = quotient / 2
print(quotient)
# Out:
# 8.0
# <class 'float'>
# 4.0

# %% [markdown]
# ##### Floor Division

# %%
result_floor = 15 // 2
print(result_floor)

#short-hand
result_floor //= 2 # result_floor // 2
print(result_floor)
# Out:
# 7
# 3

# %% [markdown]
# ##### Modulo

# %%
# return the remainder after a division problem

result_mod = 33 % 6
print(result_mod)

#short-hand
result_mod %= 2
# result_mod = result_mod % 2
print(result_mod)
# Out:
# 3
# 1

# %% [markdown]
# ##### Exponential

# %%
square = 5 ** 2
print(square)

#short-hand
square **= 2 # square = square ** 2
print(square)
# Out:
# 25
# 625

# %% [markdown]
# ### String Input-Output

# %% [markdown]
# ##### String Assignment

# %%
name1 = "Sheldon"
print(name1)
print(type(name1))
# Out:
# Sheldon
# <class 'str'>

# %%
name2 = "Sheldon"
print(name2)
print(type(name2))
# Out:
# Sheldon
# <class 'str'>

# %%
contraction1 = "you can't do that"
print(contraction1)

sentence = 'he said, "i like python"'
print(sentence)
# Out:
# you can't do that
# he said, "i like python"

# %%
contraction2 = 'you can't do that'
print(contraction2)
# Out:
#   File "/var/folders/ww/4ctxwd9d24g7_2m5hm2t2r9c0000gn/T/ipykernel_51538/1292364118.py", line 1
#     contraction2 = 'you can't do that'
#                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##### Escape Characters

# %%
print('you can\'t do that')
# Out:
# you can't do that

# %%
print('hello
      how eerr you')
# Out:
#   File "/var/folders/ww/4ctxwd9d24g7_2m5hm2t2r9c0000gn/T/ipykernel_51538/266740033.py", line 1
#     print('hello
#                 ^
# SyntaxError: EOL while scanning string literal

# %%
print('hello\
 how eerr you?')
# Out:
# hello how eerr you?

# %%
# \n
print('hello\nhow eerr \nyou?')
# Out:
# hello
# how eerr
# you?

# %%
# \t
print('hello\thow eerr you? \tI am good ma dude!')
# Out:
# hello	how eerr you? 	I am good ma dude!

# %%
# Raw String
print(r'hello\thow eerr you? \tI am good ma dude!')
# Out:
# hello\thow eerr you? \tI am good ma dude!

# %%
new_string = '''this is a multi
line string where i can print a lot and 
nothing wil happen dawg!
'''
"""like seriously it just happnes this way!
fo rea real!"""


print(new_string)
# Out:
# this is a multi
# line string where i can print a lot and
# nothing wil happen dawg!

# %% [markdown]
# ##### String Concatenation

# %%
first_name = "John"
last_name = "Smith"

full_name = first_name + " " + last_name
print(full_name)

# Short-hand version
full_name += " Jr"
print(full_name)
# Out:
# John Smith
# John Smith Jr

# %%
num_a = 10
num_b = "10"

print(num_a + num_b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/ww/4ctxwd9d24g7_2m5hm2t2r9c0000gn/T/ipykernel_51538/3681465041.py in <module>
#       2 num_b = "10"
#       3
# ----> 4 print(num_a + num_b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ##### Type Conversion

# %%
num_b_int = int(num_b)

print(num_b, type(num_b))
print(num_b_int, type(num_b_int))

print(num_a + num_b_int)
# Out:
# 10 <class 'str'>
# 10 <class 'int'>
# 20

# %%
num_a_str = str(num_a)

print(num_a, type(num_a))
print(num_a_str, type(num_a_str))

print(num_a_str + num_b)
# Out:
# 10 <class 'str'>
# 10 <class 'str'>
# 1010

# %% [markdown]
# ##### .format() and f-strings

# %%
name = "Brian"
home = "Chicago"

print("Hello my name is {} and I am from {}!".format(name, home))
# Out:
# Hello my name is Brian and I am from Chicago!

# %%
print(f"Hello my name is {name} and i am from {home}!")
# Out:
# Hello my name is Brian and i am from Chicago!

# %% [markdown]
# ##### Old Way (python 2)

# %% [markdown]
# # In-Class Exercise 1 <br>
# <p>Increase the year by 1 and then print out the following statement</p>

# %% [markdown]
# ## Exercise #1 <br>
# <p>Cube Number Test... Print out all cubed numbers up to the total value 1000. Meaning that if the cubed number is over 1000 break the loop.</p>

# %%
list_num = [i]
for i in range(1, 11, 1):
    print(i**3)
# Out:
# 1
# 8
# 27
# 64
# 125
# 216
# 343
# 512
# 729
# 1000

# %% [markdown]
# ## Exercise #2 <br>
# <p>Get first prime numbers up to 100</p>

# %%
# HINT::
# An else after an if runs if the if didn’t
# An else after a for runs if the for didn’t break
p_num = 2
num = 10

if num is / p_num:
    print("prime")
if num / p_num2:
    print("prime")
else:
    print("not prime")
# Out:
#   File "/var/folders/ww/4ctxwd9d24g7_2m5hm2t2r9c0000gn/T/ipykernel_3176/49978974.py", line 6
#     if num is / p_num:
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Exercise 3 <br>
# <p>Take in a users input for their age, if they are younger than 18 print kids, if they're 18 to 65 print adults, else print seniors</p>

# %%
required_age = 18
senior_age = 65
user_age = int(input('What is your age?'))

if user_age < required_age:
    print("You're just a kid!")
elif user_age <= senior_age:
    print("You're the adult!")
else: 
    print("You Old!")
# Out:
# What is your age?66
# You Old!
